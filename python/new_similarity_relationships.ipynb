# %% [markdown]
# # Similarity Enrichment

# %% [markdown]
# ### 0. Setup Environment

# %%
import os
from dotenv import load_dotenv
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores.neo4j_vector import Neo4jVector
from langchain import PromptTemplate, LLMChain
from langchain.chat_models import ChatOpenAI
from neo4j import GraphDatabase

load_dotenv(override=True)
uri = os.getenv("NEO4J_URI")
user = os.getenv("NEO4J_USER")
password = os.getenv("NEO4J_PASSWORD")
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')
embedding_model = OpenAIEmbeddings()

with GraphDatabase.driver(uri, auth=(user, password)) as driver:
    driver.verify_connectivity()

# %% [markdown]
# ### 1. Embeddings on Taxonomies (OpenAI)

# %%
vectorstore = Neo4jVector.from_existing_graph(
    embedding=embedding_model,
    url=uri,
    username=user,
    password=password,
    index_name='term',
    node_label="Taxonomy",
    embedding_node_property="embedding",
    text_node_properties=["title"]
)

retrieval_query = """
    MATCH (node:Taxonomy)
    WITH node, score
    return node.title AS text, score,
        node {title: node.title} 
    as metadata
    """
contextualized_vectorstore = Neo4jVector.from_existing_index(
    OpenAIEmbeddings(),
    url=uri,
    username=user,
    password=password,
    index_name="term",
    retrieval_query=retrieval_query,
)

# %% [markdown]
# ### 2. Get Top PageRank Taxonomy (Percentile 90)

# %%
top_taxonomies = []
with GraphDatabase.driver(uri, auth=(user, password)) as driver:
    records, summary, keys = driver.execute_query("""
        // 1) Gets p90 of PageRank Property
        CALL () {
            MATCH (t:Taxonomy)
            RETURN percentileCont(t.pageRank, 0.90) AS p90
        }

        // 2) Gets Taxonomies in p90 of PageRank Property
        MATCH (t:Taxonomy)
        WHERE t.pageRank >= p90
        RETURN
            t.title,
            t.pageRank
        ORDER BY t.pageRank DESC
        """,
        database_="neo4j"
    )

    for record in records:
        top_taxonomies.append(record['t.title'])

    print(top_taxonomies)
# Out:
# ['Cosmetics', 'Vehicles', 'Apparatus for locomotion by land', 'Computers', 'Telecommunication services', 'Clothing', 'Musical instruments', 'Furniture', 'Pharmaceutical preparations', 'Soap', 'Services for providing food and drink', 'Cakes', 'Motors, other than for land vehicles', 'Insurances', 'Computer software', 'Beds', 'Coffee', 'Footwear', 'Headgear', 'Industrial chemicals', 'Games', 'Machine tools', 'Streaming of audio content via a global computer network', 'Apparatus for locomotion by water', 'Computer programming', 'Guns [weapons]', 'Apparatus for locomotion by air', 'Dolls', 'Stationery', 'Business administration', 'Aceites esenciales', 'Frameworks of metal', 'Insurance services', 'Hotel services', 'Cosmetic hand care products', 'Data processing equipment', 'Jewellery', 'Travelling bags', 'Provision of food and drink', 'Teaching', 'Cards', 'Software', 'Business management', 'Magnetic data media', 'Cars', 'Fish, not live', 'Confectionery', 'Preparations for destroying vermin', 'Veterinary preparations', 'Abrasives', 'Hand tools and implements [hand-operated]', 'Perfumes', 'Non-alcoholic beverages', 'Tea', 'Edible ices', 'Medical services', 'Powertrains, including engines and motors, for land vehicles', 'Beer', 'Milk products', 'Organization of exhibitions for commercial or advertising purposes', 'Coffee percolators, electric', 'Sanitary preparations for medical purposes', 'Chocolate', 'Handbags', 'Software design and development', 'Hair lotions', 'Appliances for gymnastics', 'Photocopy paper', 'Entertainment services', 'Bags', 'Sauces [condiments]', 'Disinfectants', 'Investment services', 'Decorations for Christmas trees', 'Materials for dressings', 'Games software', 'Fertilizers', 'Herbicides', 'Preparations made from cereals', 'Computerized file management', 'Fungicides', 'Lighting apparatus', 'Table covers', 'Spices', 'Building and construction materials and elements, not of metal', 'Printed matter', 'Finance services', 'Ammunition and projectiles', 'Sound transmitting apparatus', 'Pants', 'Cocoa', 'Watches', 'Preserved vegetables', 'Advertising', 'Provision of an online marketplace for buyers and sellers of goods and services', 'Meat extracts', 'Seasonings', 'Rucksacks', 'Apparatus and instruments for accumulating electricity', 'Dietetic substances adapted for medical use', 'Textile goods, and substitutes for textile goods', 'Wine', 'Pharmaceuticals', 'Sunglasses', 'Retail services in relation to clothing', 'Furbishing preparations', 'Dried fruit', 'Cigarettes', 'Office functions services', 'Fruit, preserved', 'Toilet soap', 'Data processing apparatus', 'Teeth filling material', 'Air fragrancing preparations', 'Organization of competitions [education or entertainment]', 'Cereal-based snack food', 'Optical apparatus and instruments', 'Fruit, fresh', 'Razors', 'Perfumery', 'Handoperated knife sharpeners', 'Jams', 'Bicycles', 'Dental apparatus and instruments', 'Bleaching preparations', 'Investment funds', 'Roll-your-own tobacco', 'Electronic publications, downloadable', 'Explosives', 'Jellies for food', 'Medical apparatus and instruments', 'Veterinary apparatus and instruments', 'Vegetables, dried', 'Vegetables, cooked', 'Precious stones', 'Clerical services', 'Dentifrices', 'Magazines [periodicals]', 'Pastries', 'Umbrellas', 'Biscuits', 'Signalling apparatus', 'Construction services', 'Time instruments', 'Honey', 'Home construction services', 'Toothbrushes', 'Animal foodstuffs', 'Toiletries', 'Laundry bleach', 'Artificial flowers', 'Computer software technical support services', 'Chemical preparations for use in photography', 'Ribbons', 'Sound reproduction apparatus', 'Jackets [clothing]', 'Paintbrushes', 'Sugar', 'Apparatus for the transmission of images', 'Bed covers', 'Sweetmeats [candy]', 'Apparatus for ventilating', 'Scientific laboratory services', 'Artificial coffee', 'Design and development of computer hardware', 'Textiles and substitutes for textiles', 'Computer software, recorded', 'Shellfish, not live',  ...

# %% [markdown]
# ### 3. Similarity and Comparison from KG

# %%
# Similar Results
k = 100

with GraphDatabase.driver(uri, auth=(user, password)) as driver:

    print(f"\nFound {len(top_taxonomies)} Top Taxonomies:")

    for top_term in top_taxonomies:

        print(f"\nLooking for Similars to «{top_term}»…")

        # 1) Get Name/Score by Similarity
        similar = contextualized_vectorstore.similarity_search_with_score(
            top_term, k
        )
        print(similar)
        similar_taxonomies = [(doc.metadata["title"], score) for doc, score in similar]
        names_list = [name for name, _ in similar_taxonomies]

        # 2) Get Taxonomies not related for TopTerm
        records, summary, keys = driver.execute_query("""
            MATCH (t:Taxonomy {title: $topTerm})
            UNWIND $namesList AS candidate
            MATCH (o:Taxonomy {title: candidate})
            WHERE NOT EXISTS {
                (t)-[:HAS_SIMILARITY*1..3]-(o)
            }
            RETURN o.title AS title;
            """,
            topTerm=top_term, 
            namesList=names_list, 
            database_="neo4j"
        )

        # 3) Not related Name/Score List
        not_related = {r["title"] for r in records}
        result = [
            (title, score)
            for title, score in similar_taxonomies
            if title in not_related
        ]
        
        print(f"Similars with no Previous Relation ({len(result)} of {k}):")
        for title, score in result:
            print(f"  • {title}: {score:.4f}")

        break
# Out:
# Found 268 Top Taxonomies:
#
# Looking for Similars to «Cosmetics»…
# [(Document(metadata={'title': 'Cosmetics'}, page_content='Cosmetics'), 0.9518890380859375), (Document(metadata={'title': 'Cosmetics products'}, page_content='Cosmetics products'), 0.94366455078125), (Document(metadata={'title': 'Cosmetics and beauty preparations'}, page_content='Cosmetics and beauty preparations'), 0.9397735595703125), (Document(metadata={'title': 'Cosmetic creams'}, page_content='Cosmetic creams'), 0.936309814453125), (Document(metadata={'title': 'Cosmetic preparations for skin care'}, page_content='Cosmetic preparations for skin care'), 0.9349517822265625), (Document(metadata={'title': 'Application of cosmetic products to the body'}, page_content='Application of cosmetic products to the body'), 0.93353271484375), (Document(metadata={'title': 'Application of cosmetic products to the face'}, page_content='Application of cosmetic products to the face'), 0.9334869384765625), (Document(metadata={'title': 'Consultancy services relating to cosmetics'}, page_content='Consultancy services relating to cosmetics'), 0.932952880859375), (Document(metadata={'title': 'Cosmetic, hygiene and beauty care utensils'}, page_content='Cosmetic, hygiene and beauty care utensils'), 0.9326324462890625), (Document(metadata={'title': 'Cosmetic utensils'}, page_content='Cosmetic utensils'), 0.9311981201171875), (Document(metadata={'title': 'Face creams for cosmetic use'}, page_content='Face creams for cosmetic use'), 0.9295501708984375), (Document(metadata={'title': 'Applicators for cosmetics'}, page_content='Applicators for cosmetics'), 0.929443359375), (Document(metadata={'title': 'Cosmetic hand care products'}, page_content='Cosmetic hand care products'), 0.9294281005859375), (Document(metadata={'title': 'Cosmetic and toilet utensils'}, page_content='Cosmetic and toilet utensils'), 0.9294281005859375), (Document(metadata={'title': 'Chemical compositions and materials for use in the manufacture of cosmetics'}, page_content='Chemical compositions and materials for use in the manufacture of cosmetics'), 0.928802490234375), (Document(metadata={'title': 'Cosmetics consultancy services'}, page_content='Cosmetics consultancy services'), 0.9268646240234375), (Document(metadata={'title': 'Cosmetic treatment'}, page_content='Cosmetic treatment'), 0.9249420166015625), (Document(metadata={'title': 'Oils for cosmetic purposes'}, page_content='Oils for cosmetic purposes'), 0.9246368408203125), (Document(metadata={'title': 'Make-up'}, page_content='Make-up'), 0.9245147705078125), (Document(metadata={'title': 'Beauty care'}, page_content='Beauty care'), 0.9239501953125), (Document(metadata={'title': 'Cosmetic analysis'}, page_content='Cosmetic analysis'), 0.923126220703125), (Document(metadata={'title': 'Cosmetic preparations for the care of mouth and teeth'}, page_content='Cosmetic preparations for the care of mouth and teeth'), 0.922119140625), (Document(metadata={'title': 'Cosmetic treatment for the hair'}, page_content='Cosmetic treatment for the hair'), 0.92169189453125), (Document(metadata={'title': 'Body cleaning and beauty care preparations'}, page_content='Body cleaning and beauty care preparations'), 0.9182281494140625), (Document(metadata={'title': 'Human hygiene and beauty care'}, page_content='Human hygiene and beauty care'), 0.9179229736328125), (Document(metadata={'title': 'Consultancy services relating to beauty'}, page_content='Consultancy services relating to beauty'), 0.9174652099609375), (Document(metadata={'title': 'Pharmaceutical preparations for skin care'}, page_content='Pharmaceutical preparations for skin care'), 0.9165496826171875), (Document(metadata={'title': 'Toiletries'}, page_content='Toiletries'), 0.91650390625), (Document(metadata={'title': 'Beauty care for human beings'}, page_content='Beauty care for human beings'), 0.9163970947265625), (Document(metadata={'title': 'Skin, eye and nail care preparations'}, page_content='Skin, eye and nail care preparations'), 0.916107177734375), (Document(metadata={'title': 'Skin c ...
# Similars with no Previous Relation (31 of 100):
#   • Cosmetic, hygiene and beauty care utensils: 0.9326
#   • Face creams for cosmetic use: 0.9296
#   • Chemical compositions and materials for use in the manufacture of cosmetics: 0.9288
#   • Body cleaning and beauty care preparations: 0.9182
#   • Skin, eye and nail care preparations: 0.9161
#   • Skin care creams, other than for medical use: 0.9146
#   • Feminine hygiene products: 0.9116
#   • Cosmetic bags sold empty: 0.9107
#   • Perfumery and fragrances: 0.9077
#   • Glasses, sunglasses and contact lenses: 0.9060
#   • Soaps and gels: 0.9059
#   • Skin pomades: 0.9044
#   • Rental of equipment for human hygiene and beauty care: 0.9039
#   • Decorative articles for the hair: 0.9034
#   • Hairsprays: 0.9033
#   • Chemical preparations for use in photography: 0.9032
#   • Hair styling appliances: 0.9029
#   • Body soaps: 0.9029
#   • Hair removal and shaving preparations: 0.9029
#   • Skin moisturisers: 0.9026
#   • Cleaning and fragrancing preparations, other than for personal use: 0.9023
#   • Toiletry bags: 0.9020
#   • Oral hygiene preparations: 0.9019
#   • Deodorants and antiperspirants: 0.9014
#   • Shaving cream: 0.9011
#   • Hair ornaments, hair rollers, hair fastening articles, and false hair: 0.9010
#   • Hair pomades: 0.9007
#   • Medical dressings, coverings and applicators: 0.9005
#   • Bath preparations, not for medical purposes: 0.9000
#   • Bath preparations: 0.8998
#   • Hair gel: 0.8997

# %% [markdown]
# ### 4. Other uses: similarity by class text, found and retrieve all Taxonomies

# %%
vectorstore2 = Neo4jVector.from_existing_graph(
    embedding=embedding_model,
    url=uri,
    username=user,
    password=password,
    index_name='class',
    node_label="Class",
    embedding_node_property="embedding",
    text_node_properties=["text"]
)

retrieval_query2 = """
    MATCH (t)<-[rc:HAS_CHILD*]-(node:Class)<-[rcat]-(category)
    WITH node, category, collect(t.title) AS taxonomies, score
    RETURN node.text AS text, score,
        node {title: node.title, text: node.text, category: category.title, taxonomies: taxonomies} 
    AS metadata
    """
contextualized_vectorstore2 = Neo4jVector.from_existing_index(
    OpenAIEmbeddings(),
    url=uri,
    username=user,
    password=password,
    index_name="class",
    retrieval_query=retrieval_query2,
)

# %%
question = "It provides comprehensive IT and technology services—including software and hardware development, hosting and SaaS, consultancy and security, data processing and testing, design, and related equipment rentals."
def kg_class_response(input):
  response = contextualized_vectorstore2.similarity_search_with_score(input, k=3)
  return "\n".join([
        f"\nScore: {score}\nTitle: {doc.metadata.get('title')}\nCategory: {doc.metadata.get('category')}\nText: {doc.metadata.get('text')}\nTaxonomies: {doc.metadata.get('taxonomies')}."
        for doc, score in response
    ])
print(kg_class_response(question))
# Out:
# Score: 0.941558837890625
# Title: 42
# Category: Services
# Text: <ol><li>IT services namely Software development, programming and implementation, Computer hardware development, Hosting services, and software as a service and rental of software, Rental of computer hardware and facilities, IT consultancy, advisory and information services, IT security, protection and restoration, Data duplication and conversion services, data coding services, Computer analysis and diagnostics, Research, development and implementation of computers and systems, Computer project management services, Data mining, Digital watermarking, Computer services, Technological services relating to computers</li><li>Science and technology services</li><li>Testing, authentication and quality control</li><li>Design services</li><li>And rental, hire and leasing in connection with the aforesaid, included in the class and advice, consultancy and information for the aforesaid, included in the class Computer network services, Updating of memory banks of computer systems, Data migration services, Updating websites for others, Monitoring of computer systems by remote access</li></ol>
# Taxonomies: ['Installing computer programs', 'Maintenance of computer software', 'Database design and development', 'Computer programming', 'Conversion of data or documents from physical to electronic media', 'Software design and development', 'Hosting computer websites', 'Maintenance of computer programs', 'Development of computer programs', 'Software development', 'Updating of computer software', 'Architectural services', 'Duplication of computer programs', 'Computer software design', 'Electronic data storage', 'Industrial analysis services', 'Computer software consultancy', 'Server hosting', 'Software as a service [SaaS]', 'Scientific laboratory services', 'Computer system analysis', 'Creating, maintaining, and modernizing computer software', 'Computer software technical support services', 'Conversion of computer programs and data, other than physical conversion', 'Design of computer hardware', 'Design and development of computer hardware', 'Recovery of computer data', 'Information technology support services', 'Creation of computer programmes for data processing', 'Consultancy services relating to technological research', 'Design of headgear', 'Dress designing', 'Installation of computer software', 'Computer software design and updating', 'Electronic storage of documents', 'Biological research', 'Pharmaceutical research and development', 'Scientific services and research relating thereto', 'Laboratory research services relating to pharmaceuticals', 'Technological services and design relating thereto', 'Technological services and research relating thereto', 'Rental of computer software', 'Design of information systems', 'Consultancy services for designing information systems', 'Design of software for processing and distribution of multimedia contents', 'Design of computers for others', 'Scientific research', 'Research services', 'Installation, maintenance and updating of computer software', 'Technical consultancy services relating to information technology', 'Conducting technical project studies', 'Consultancy in the field of computers', 'Design and development of telecommunications networks', 'Computer system design', 'Consultation services relating to computer systems', 'Cloud computing', 'Developing and updating computer software', 'Computer software programming services', 'Information technology [IT] consultancy', 'Creating of computer programs', 'Design, maintenance and up-dating of computer software', 'Software design for others', 'Consultancy in the design and development of computer hardware', 'Installation and maintenance of computer programs', 'Hosting of digital content on the Internet', 'Computer services for the analysis of data', 'Development and testing of computing methods, algorithms and software', 'Design and development of electronic database software', 'Design and development of data entry systems', 'Design and development of data processing systems', 'Design and development of data display systems', 'Design and development of data storage systems', 'Design and development of systems for data input, output, processing, display and storage', 'Design and development of wireless data transmission apparatus, instruments and equipment', 'Design and development of wireless data transmission apparatus', 'Computer rental', 'Remote computer backup services', 'Platform as a service [PaaS]', 'Integration of computer systems and networks', 'Development of computer systems', 'Disaster recovery services for computer systems', 'Updating and upgrading of computer software', 'Application service provider [ASP], namely, hosting computer software applications of others', 'Data security services', 'Data mining', 'Disaster recovery services for data communications systems', 'Development of systems for the storage of data', 'Updating of software databases', 'Monitoring of computer systems by remote access', 'Application service provider services', 'Computer disaster recovery planning', 'Development of systems for the processi ...
#
# Score: 0.9050445556640625
# Title: 38
# Category: Services
# Text: <ol><li>Telecommunication services</li><li>Provision and rental of telecommunications facilities and equipment</li><li>And rental, hire and leasing in connection with the aforesaid, included in the class and advice, consultancy and information for the aforesaid, included in the class.</li></ol>
# Taxonomies: ['Streaming of audio content via a global computer network', 'Providing user access to global computer networks', 'Transmission of telegrams', 'Transmission of electronic mail', 'Voice mail services', 'Rental of telecommunication equipment', 'Communications by telegrams', 'Telegraph services', 'Providing online forums', 'Transmission of greeting cards online', 'Providing access to databases', 'Rental of facsimile apparatus', 'Providing telecommunication channels for teleshopping services', 'Rental of modems', 'Rental of telephones', 'Providing telecommunications connections to a global computer network', 'Rental of access time to global computer networks', 'Paging services [radio, telephone or other means of electronic communication]', 'Facsimile transmission', 'Telex services', 'Telecommunications routing and junction services', 'Providing internet chatrooms', 'Providing information in the field of telecommunications', 'Rental of message sending apparatus', 'News agency services', 'Transmission of data via the Internet', 'Electronic messaging', 'Telematic [data communication] services', 'Operation of radio frequency communications systems', 'Operation of a telecommunications network', 'Operating of electronic communications networks', 'Data transmission', 'Information transmission services via digital networks', 'Transmission of digital information', 'Operation of telecommunications systems', 'Operating of electronic communications systems', 'Interactive telecommunications services', 'Computer intercommunication', 'Provision of internet access services', 'Mobile telephone communication services', 'Computer communication services', 'Telecommunication services', 'Broadcasting services', 'Telephone and mobile telephone services', 'Computer communication and Internet access', 'Provision of access to content, websites and portals', 'Provision and rental of telecommunications facilities and equipment'].
#
# Score: 0.8928070068359375
# Title: 41
# Category: Services
# Text: <ol><li>Publishing and reporting</li><li>Education, entertainment and sport services</li><li>Translation and interpretation</li><li>And rental, hire and leasing in connection with the aforesaid, included in the class and advice, consultancy and information for the aforesaid, included in the class.</li></ol>
# Taxonomies: ['Publication of printed material', 'Organization of competitions [education or entertainment]', 'Writing of texts, other than publicity texts', 'Rental of audio equipment', 'Production of musical videos', 'Arranging of musical events', 'Providing recreation facilities', 'Publication of published and printed matter periodicals and books in electronic form including on intranets and the internet', 'Training', 'Teaching', 'Organization of sports competitions', 'Publishing and reporting', 'Subtitling', 'Sporting services', 'Publishing services', 'Production of shows', 'Production of radio and television programmes', 'Editing of television programmes', 'Editing of radio programmes', 'Dubbing', 'Entertainment services', 'Publication of texts, other than publicity texts', 'Provision of education on-line from a computer database or via the internet or extranets', 'Cultural activities', 'Sporting activities', 'Non downloadable online publication', 'Electronic publications nondownloadable', 'Arranging and conducting of games', 'Arranging of games', 'Providing online electronic publications, not downloadable', 'Rental of video screens', 'Film production services', 'Dance hall services', 'Organising of recreational events', 'Provision of recreational events', 'Providing online publications', 'Correspondence courses', 'Arranging of exhibitions for cultural or educational purposes', 'Mobile library services', 'Arranging and conducting of sports competitions', 'Arranging of award ceremonies', 'Arranging of award ceremonies to recognise achievement', 'Providing electronic publications', 'Providing publications from a global computer network or the internet which may be browsed', 'Sporting results services', 'Racing information services', 'Television show production', 'Provision of training and education', 'Production of sporting events for film', 'Booking of seats for concerts', 'Concert booking', 'Sporting and cultural activities', 'Booking of seats for shows', 'Sports training', 'Organization of competitions', 'Organization of lotteries', 'Casino services', 'Publishing, reporting, and writing of texts', 'Education, entertainment and sport services', 'Organisation of conferences, exhibitions and competitions', 'Gambling services', 'Audio, video and multimedia production, and photography', 'Sports and fitness services', 'Education and instruction services', 'Rental services relating to equipment and facilities for education, entertainment, sports and culture', 'Library services and rental of media', 'Rental of sports equipment and facilities', 'Rental of audio/visual and photographic equipment and facilities', 'Amusement and theme parks, fairs, zoos and museums', 'Live performance services', 'Video game services', 'Translation and interpretation', 'Ticket reservation and booking services for education, entertainment and sports activities and events'].

# %%
template = '''
You are an expert assistant retrieving information about Taxonomies for users in a company. The user will ask you about this Class:
  "{user_query}"

You have found the following classes most relevant to the question:
{classes}

For these class you have the following:
	•	Score: Similarity score for the guideline
	•	Title: Number of the Class
	•	Text: HTML text that makes a summary of the Class
	•	Taxonomies: All the taxonomies included in this class

Generate a humanized response that includes in a sentence the Title as a number and a Summary from the text of the highest-scoring class and also list all its taxonomies.

At the end, include the titles of the other Class in case they may be useful to the user, with a question like: Other classes you were expecting?.
'''

prompt = PromptTemplate(
    input_variables=["user_query", "classes"],
    template=template
)

llm = ChatOpenAI(model="gpt-4o", temperature=0.7)
chain = LLMChain(llm=llm, prompt=prompt)

def humanized_response(question):
    classes = kg_class_response(question)
    enriched = chain.predict(user_query=question, classes=classes)
    return enriched

response = humanized_response(kg_class_response(question))
print(response)
# Out:
# Certainly! The class with the highest relevance score is Class **42**. This class primarily encompasses a wide range of IT and technology-related services. The summary of this class includes IT services such as software development, programming, implementation, computer hardware development, hosting services, software as a service, and rental of software. It also covers IT consultancy, advisory and information services, IT security, data duplication, conversion services, computer analysis, diagnostics, research and development of computers and systems, and computer project management services. Additionally, it involves science and technology services, testing, authentication, quality control, design services, and various related consulting services.
#
# Here is a comprehensive list of taxonomies included in Class 42:
# - Installing computer programs
# - Maintenance of computer software
# - Database design and development
# - Computer programming
# - Conversion of data or documents from physical to electronic media
# - Software design and development
# - Hosting computer websites
# - Maintenance of computer programs
# - Development of computer programs
# - Software development
# - Updating of computer software
# - Architectural services
# - Duplication of computer programs
# - Computer software design
# - Electronic data storage
# - Industrial analysis services
# - Computer software consultancy
# - Server hosting
# - Software as a service [SaaS]
# - Scientific laboratory services
# - Computer system analysis
# - Creating, maintaining, and modernizing computer software
# - Computer software technical support services
# - Conversion of computer programs and data, other than physical conversion
# - Design of computer hardware
# - Design and development of computer hardware
# - Recovery of computer data
# - Information technology support services
# - Creation of computer programmes for data processing
# - Consultancy services relating to technological research
# - Design of headgear
# - Dress designing
# - Installation of computer software
# - Computer software design and updating
# - Electronic storage of documents
# - Biological research
# - Pharmaceutical research and development
# - Scientific services and research relating thereto
# - Laboratory research services relating to pharmaceuticals
# - Technological services and design relating thereto
# - Technological services and research relating thereto
# - Rental of computer software
# - Design of information systems
# - Consultancy services for designing information systems
# - Design of software for processing and distribution of multimedia contents
# - Design of computers for others
# - Scientific research
# - Research services
# - Installation, maintenance and updating of computer software
# - Technical consultancy services relating to information technology
# - Conducting technical project studies
# - Consultancy in the field of computers
# - Design and development of telecommunications networks
# - Computer system design
# - Consultation services relating to computer systems
# - Cloud computing
# - Developing and updating computer software
# - Computer software programming services
# - Information technology [IT] consultancy
# - Creating of computer programs
# - Design, maintenance and up-dating of computer software
# - Software design for others
# - Consultancy in the design and development of computer hardware
# - Installation and maintenance of computer programs
# - Hosting of digital content on the Internet
# - Computer services for the analysis of data
# - Development and testing of computing methods, algorithms and software
# - Design and development of electronic database software
# - Design and development of data entry systems
# - Design and development of data processing systems
# - Design and development of data display systems
# - Design and development of data storage systems
# - Design and development of systems for data input, output, processing, display and storage
# - Design and development of wireless data transmission apparatus, instruments and equipment
# - Design and development of wireless data transmission apparatus
# - Computer rental
# - Remote computer backup services
# - Platform as a service [PaaS]
# - Integration of computer systems and networks
# - Development of computer systems
# - Disaster recovery services for computer systems
# - Updating and upgrading of computer software
# - Application service provider [ASP], namely, hosting computer software applications of others
# - Data security services
# - Data mining
# - Disaster recovery services for data communications systems
# - Development of systems for the storage of data
# - Updating of software databases
# - Monitoring of computer systems by remote access
# - Application service provider services
# - Computer disaster recovery planning
# - Development of systems for the processing of data
# - Research and development of new products for others
# - Creating and maintaining websites for others
# - Computer security system monitoring services
# - Providing search engines for obtaining data via communications networks
# - Development of programmes for data processing
# - Design, creation, hosting and maintenance of websites for others
# - Rental of computer hardware
# - Providing information relating to computer technology and programming via a website
# - Repair of computer software
# - Providing search engines for the internet
# - Creating electronically stored web pages for online services and the internet
# - Rental of web servers
# - Consultation services relating to computer hardware
# - Encryption, decryption and authentication of information, messages and data
# - Technological research
# - Server administration
# - Rental of operating software for accessing and using a cloud computing network
# - Rental of operating software for computer networks and servers
# - Rental of memory space on servers for hosting electronic bulletin boards
# - Hosting the web sites of others on a computer server for a global computer network
# - Footwear design services
# - IT services
# - Software development, programming and implementation
# - Computer hardware development
# - Hosting services, software as a service, and rental of software
# - Rental of computer hardware and facilities
# - IT consultancy, advisory and information services
# - IT security, protection and restoration
# - Data duplication and conversion services, data coding services
# - Science and technology services
# - Rental of science and technology equipment
# - Medical and pharmacological research services
# - Engineering services
# - Surveying and exploration services
# - Architectural and urban planning services
# - Natural science services
# - Earth science services
# - Testing, authentication and quality control
# - Design services
# - Design services for IT
# - Design services for architecture, and interior and exterior design for buildings
# - Design services for clothing, headgear and footwear
# - Design services for vehicles
# - Web and graphic design
#
# Other classes you might be interested in include:
# - Title: 38
# - Title: 35
#
# Are these other classes useful to you, or do you need information on a different class?
